# %% [markdown]
# ---

# %% [markdown]
# # <center><b><span style="color:orange;">AIMS RWANDA - Preparatory Class</span></b></center>
# # <center><b><span style="color:blue;">Assignment PP1 : Dictionaries, Comprehensions & Functions</span></b></center>
#
# **Instructions**
#
# - **<span style="color:red">Do not rename any function or change its parameters</span>**. Doing so will lead to a zero mark on the question.
# - Fill in the body of each function so it **returns** (not just prints) the value described.
# - You may add helper functions/cells above a stub if you need them, but the required function must still exist with the exact signature shown.
# - Run every cell before submitting so you know your code executes without errors.
# - The bonus questions are entirely optional. However, you are encouraged to try them to enforce the concepts studied in this module.
# - If your email address is `aremeline.dembo@gmail.com`, save your file as `aremeline.dembo_PP1.ipynb` before submitting. Wrong file names will not be tolerated and will lead to a zero on the assignment.
# - <span style="color:red">The use of LLMs or any AI tools to generate answers is strictly probihibited. Any such submission is automatically cancelled and the student scores zero on the assignment.</span>

# %% [markdown]
# ---
#
# ### $\text{Question 1: Cohort Averages. [8 Points]}$
#
# At the end of each trimester, AIMS collects assessment scores from several small study groups.
# Each group's scores are recorded as its own list, and all the groups together are stored as a
# **list of lists**, e.g.
#
# $$\big[\,[62, 71, 80],\; [95, 88],\; [40]\,\big]$$
#
# The academic director wants to flag every score that is *above the overall average* across
# **all** groups combined, so those students can be considered for the peer-tutoring program.
# The flagged scores should be reported from highest to lowest, so the strongest performers
# are listed first.
#
# For example, given the groups above, the overall average is $\dfrac{62+71+80+95+88+40}{6} \approx 72.67$,
# so the flagged scores are $[95, 88, 80]$.
#
# Write a function `above_average_flat(nested)` that takes a list of lists of numbers and returns
# the list of scores strictly greater than the overall average, sorted in descending order.

# %%
def above_average_flat(nested):
    """Return, in descending order, every value in `nested` strictly above
    the average of all values combined."""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 2: What Are We Talking About? [10 Points]}$
#
# A tutor recorded the class discussion as one long block of text and wants a quick way to see
# which words came up most, so they can review the concepts that generated the most conversation.
#
# Punctuation should be ignored (treat `"dog."`, `"dog!"`, and `"dog"` as the same word), and the
# comparison should be case-insensitive (`"Dog"` and `"dog"` count as the same word).
#
# Write a function `word_frequency(text)` that returns a list of `(word, count)` tuples, sorted by
# count from highest to lowest. If two words tie on count, break the tie alphabetically.
#
# **Example:**
# ```python
# word_frequency("Cat cat dog. Dog Dog!")
# # [('dog', 3), ('cat', 2)]
# ```

# %%
def word_frequency(text):
    """Return (word, count) tuples from `text`, sorted by count descending
    then alphabetically, ignoring case and the punctuation . , ! ?"""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 3: Who's In My Class? [8 Points]}$
#
# Recall the `cohort_2026` dictionary from Lesson 1, mapping each student's name to a small
# dictionary of their details, including a `"favorite_subject"` key:
#
# ```python
# cohort_2026 = {
#     "Uwase":  {"age": 19, "favorite_subject": "Python"},
#     "Eric":   {"age": 21, "favorite_subject": "Calculus"},
#     "Grace":  {"age": 20, "favorite_subject": "Python"},
# }
# ```
#
# The department wants the *reverse* view: for each subject, which students prefer it? That way
# they know how many teaching assistants to assign to each topic.
#
# Write a function `group_by_subject(cohort)` that takes a dictionary shaped like `cohort_2026`
# and returns a dictionary mapping each subject to the **sorted** list of names of students who
# chose it as their favorite.

# %%
def group_by_subject(cohort):
    """Return a dict mapping subject -> sorted list of student names who
    listed it as their favorite_subject."""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 4: Grading With Weights. [12 Points]}$
#
# Most courses don't weigh every assessment equally. An exam usually counts for more than a
# homework set, which usually counts for more than a quiz. AIMS wants a single flexible grading
# function that works no matter how many components a course has.
#
# You will receive the raw scores as **positional arguments**, and the weight of each component
# (in the *same order* the scores were given) as **keyword arguments**, e.g.
#
# ```python
# weighted_average(80, 90, 70, exam=0.5, homework=0.3, quiz=0.2)
# ```
#
# Here, $80$ is weighted by $0.5$ (the first keyword argument's value), $90$ by $0.3$, and $70$ by
# $0.2$. You may assume the number of scores always matches the number of weights, and that the
# weights sum to $1$.
#
# Write a function `weighted_average(*scores, **weights)` that returns the weighted average,
# rounded to 2 decimal places.

# %%
def weighted_average(*scores, **weights):
    """Return the weighted average of `scores`, weighted (in order) by the
    values of `weights`, rounded to 2 decimal places."""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 5: The Roster Bug. [10 Points]}$
#
# A teaching assistant wrote a function to add students to a class roster, using a default empty
# list for whenever no existing roster is passed in:
#
# ```python
# def add_student(name, roster=[]):
#     roster.append(name)
#     return roster
# ```
#
# They tested it once and it worked fine. But a few days later, strange things started happening:
# names from *previous, unrelated* calls kept reappearing in rosters that should have started
# empty! Something about Python's handling of default arguments is biting them.
#
# Your task is to write a **correct** version of this function that avoids the bug entirely.
#
# Write a function `add_student(name, roster=None)` that appends `name` to `roster` and returns
# it. If no `roster` is given, a **fresh, independent** list should be created and used for that
# call only — it must never carry over names from a previous call that also omitted `roster`.

# %%
def add_student(name, roster=None):
    """Append `name` to `roster` and return it. If `roster` is None, start
    a brand-new list for this call only (avoid the mutable-default bug)."""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 6: Digit Sums, the Recursive Way. [8 Points]}$
#
# The digit sum of a number is simply the sum of its digits, e.g. the digit sum of $9875$ is
# $9 + 8 + 7 + 5 = 29$.
#
# There's a neat recursive way to compute this without ever converting the number to a string:
# the last digit of $n$ is $n \bmod 10$, and the rest of the digits form the number
# $n \ // \ 10$ — so the digit sum of $n$ is the last digit plus the digit sum of the rest.
#
# Write a function `digit_sum_recursive(n)` that returns the digit sum of a non-negative integer
# `n` **using recursion only** — no loops, and no converting `n` to a string.

# %%
def digit_sum_recursive(n):
    """
    Return the sum of the digits of a non-negative integer n, using recursion
    (no loops, no str(n) conversion allowed).
    """

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 7: Digging Through the Records. [12 Points]}$
#
# AIMS stores some administrative data as deeply nested dictionaries (and sometimes lists inside
# those dictionaries), e.g.
#
# ```python
# records = {
#     "cohort_2026": {
#         "students": ["Uwase", "Eric", "Grace"],
#         "coordinator": {"name": "Dr. Mugenzi", "office": "B12"}
#     }
# }
# ```
#
# Reaching into a specific piece of data means chaining several lookups together, e.g.
# `records["cohort_2026"]["coordinator"]["office"]`. But if *any* key along that chain doesn't
# exist, Python crashes with a `KeyError` (or `IndexError` for lists) — which is a problem when
# you're not sure the data is complete.
#
# Write a function `deep_get(d, keys, default=None)` that walks through the nested structure `d`
# following the path described by the list `keys` (keys can be dictionary keys or list indices,
# mixed together), and returns whatever value it finds. If the path is invalid at any point, it
# must return `default` instead of crashing.
#
# **Examples:**
# ```python
# deep_get({"a": {"b": [10, 20]}}, ["a", "b", 1])       # 20
# deep_get({"a": {}}, ["a", "b"], "N/A")                # "N/A"
# ```

# %%
def deep_get(d, keys, default=None):
    """
    d: a nested dictionary.
    keys: a list of keys/indices to walk through, e.g. ["a", "b", 0]
    Return the value found at that path, or `default` if any key is missing
    along the way (must not crash).
    """

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 8: Flip It. [8 Points]}$
#
# A matrix stored as a list of rows, e.g. $\begin{bmatrix}1 & 2 & 3\\4 & 5 & 6\end{bmatrix}$
# represented as `[[1, 2, 3], [4, 5, 6]]`, sometimes needs to be transposed — turning rows into
# columns — so that the result is $\begin{bmatrix}1 & 4\\2 & 5\\3 & 6\end{bmatrix}$.
#
# Write a function `transpose(matrix)` that takes a rectangular list of lists and returns its
# transpose. Your solution must be written as a **single list comprehension** — no manual loops
# with `.append()`.

# %%
def transpose(matrix):
    """
    matrix: list of lists (rectangular), e.g. [[1,2,3],[4,5,6]]
    Return the transposed matrix using ONE list comprehension line
    (no manual loops with append).
    """

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 9: The Most Popular Answer. [12 Points]}$
#
# Suppose a dictionary records each student's answer to a multiple-choice question, mapping
# student name to their chosen option, e.g.
#
# ```python
# answers = {"a": 1, "b": 2, "c": 1, "d": 3, "e": 2}
# ```
#
# Here, options $1$ and $2$ are each chosen twice, more than any other option, so students
# `a`, `b`, `c`, and `e` all picked one of the most popular answers.
#
# Write a function `most_common_values(d)` that takes such a dictionary and returns a **sorted**
# list of every key whose value is one of the most frequently occurring value(s) in `d`. If there
# is a single most common value, only keys mapped to it should appear; if several values are
# tied for most common, keys mapped to *any* of them should appear.

# %%
def most_common_values(d):
    """
    d: a dict of key -> value (values can repeat).
    Find whichever value(s) occur most often among d's values, and return
    a sorted list of ALL keys that map to any of those most-common value(s).
    """

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Question 10: Pipelines. [12 Points]}$
#
# In data processing, it's common to apply several transformations to a value, one after another
# — clean it, then convert it, then round it, for instance. Rather than writing this out by hand
# every time, we can build a single function that chains any number of functions together.
#
# If $f$ and $g$ are functions, "composing" them so that $f$ runs first and $g$ runs second means
# building a new function $h$ such that $h(x) = g(f(x))$.
#
# Write a function `compose(*funcs)` that accepts any number of functions and returns a **new**
# function which applies them in the order given, left to right.
#
# **Example:**
# ```python
# add_one = lambda x: x + 1
# double   = lambda x: x * 2
#
# pipeline = compose(add_one, double)
# pipeline(3)   # 8   ->  double(add_one(3)) = double(4) = 8
# ```

# %%
def compose(*funcs):
    """
    Return a NEW function that applies the given functions in the order given
    (left to right), e.g. compose(f, g)(x) == g(f(x)).
    Must work for any number of functions, using *args and a returned function/lambda.
    """

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Bonus: Prime Detective. [15 Points]}$
#
# A number $n$ (greater than $1$) is **prime** if it has no divisors other than $1$ and itself.
# The most direct way to check this is to try dividing $n$ by every number from $2$ up to
# $n - 1$ and see if any of them divide evenly. If none do, $n$ is prime.
#
# You can actually stop much earlier: if $n$ has a divisor larger than $\sqrt{n}$, it must also
# have a matching divisor *smaller* than $\sqrt{n}$ (since divisors pair up), so checking only
# up to $\sqrt{n}$ is enough to be sure. This makes your function noticeably faster for large
# numbers.
#
# **Part (a).** Write a function `is_prime(n)` that returns `True` if `n` is prime and `False`
# otherwise. Handle edge cases sensibly: numbers less than $2$ are never prime.
#
# **Part (b).** Using `is_prime`, write a function `primes_up_to(n)` that returns a list of every
# prime number from $2$ up to and including `n`, using a **list comprehension** that calls
# `is_prime` inside it.
#
# **Example:**
# ```python
# is_prime(17)        # True
# is_prime(1)          # False
# primes_up_to(20)     # [2, 3, 5, 7, 11, 13, 17, 19]
# ```

# %%
def is_prime(n):
    """Return True if n is a prime number, False otherwise."""

    # YOUR CODE HERE

    pass


def primes_up_to(n):
    """Return a list of all prime numbers from 2 up to and including n,
    using a list comprehension that calls is_prime()."""

    # YOUR CODE HERE

    pass

# %% [markdown]
# ---
#
# ### $\text{Bonus: Math in Music. [30 Points]}$
#
# Below are the notes used in music: $\big[\text{C, C\#, D, D\#, E, F, F\#, G, G\#, A, A\#, B}\big]$
#
# For instance, the notes for the $C$ major chord are $C, E, G$.
#
# A mathematical way to get this is that $E$ is $4$ steps past $C$ and $G$ is $7$ steps past $C$. This works for any base (starter key). Again, you will see that the notes for $D$ major are $D$, $F\#$, $A$. We can therefore represent the major chord steps as a list with two elements: $\big[4, 7\big]$.
#
# The corresponding lists for some other chord types are shown below:
#
#     – Minor: [3, 7]
#     – Dominant seventh: [4, 7, 10]
#     – Augmented fifth: [4, 8]
#     – Minor seventh: [3, 7, 10]
#     – Minor fifth: [4, 6]
#     – Major seventh: [4, 7, 11]
#     – Major sixth: [4, 7, 9]
#     – Diminished seventh: [3, 6, 10]
#     – Minor sixth: [3, 7, 9]
#
# Write a function that asks the user for the key and the chord type and prints out the notes of the chord. Use a dictionary whose keys are the (musical) keys and whose values are the lists of steps.
