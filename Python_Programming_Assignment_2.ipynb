# %% [markdown]
# # <center><b><span style="color:orange;">AIMS RWANDA - Preparatory Class</span></b></center>
# # <center><b><span style="color:blue;">Assignment PP2 : Numpy, Map & Reduce</span></b></center>
#
# **Instructions**
#
# - **<span style="color:red">Do not rename any function or change its parameters.</span>** Doing so will lead to a zero mark on the question.
# - Fill in the body of each function so it **returns** (not just prints) the value described.
# - You may add helper functions/cells above a stub if you need them, but the required function must still exist with the exact signature shown.
# - If your email address is `aremeline.dembo@gmail.com`, save your file as `aremeline.dembo_PP2.ipynb` before submitting. Wrong file names will not be tolerated and will lead to a zero on the assignment.
# - In case you are working outside of the Google Colab environment, you can run `pip install numpy` in your terminal to get the `numpy` library which is used in this assignment.
# - <span style="color:red">Run every cell before submitting so you know your code executes without errors.</span>
# - <span style="color:red">The use of LLMs or any AI tools to generate answers is strictly probihibited. Any such submission is automatically cancelled and the student scores zero on the assignment.</span>

# %%
import numpy as np

# %% [markdown]
# # Question 1a — Matrix Multiplication
#
# Write a function that takes two matrices as input and returns their matrix product using NumPy.
#
# The matrices should be represented as NumPy arrays.
#
# For example, given
#
# $$
# A =
# \begin{pmatrix}
# 1 & 2 \\
# 3 & 4
# \end{pmatrix},
# \qquad
# B =
# \begin{pmatrix}
# 5 & 6 \\
# 7 & 8
# \end{pmatrix},
# $$
#
# the function should return
#
# $$
# AB =
# \begin{pmatrix}
# 19 & 22 \\
# 43 & 50
# \end{pmatrix}.$$

# %%
def matrix_product(A, B):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 1b - Eigenvalues and Eigenvectors
#
# Write a function that takes a square matrix as input and computes its eigenvalues and corresponding eigenvectors using NumPy. The function should return both the eigenvalues and eigenvectors. Test the function with an appropriate square matrix.

# %%
def eigenvalues_and_eigenvectors(A):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 2a - Gaussian Random Sample Statistics
#
# Generate a random sample of size 1000 from a Gaussian (normal) probability distribution using NumPy. Write a function that takes the sample as input and computes its mean, median, and standard deviation using NumPy's statistical functions. The function should return the three statistics in the following order:
#
# 1. Mean
# 2. Median
# 3. Standard deviation
#
# Test your function using the generated sample and display the returned values.

# %%
gaussian_sample = ...

def sample_statistics(sample):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 2b - Correlation Coefficient
#
# Generate two random samples of size 1000 from Gaussian (normal) probability distributions using NumPy. Write a function that takes the two samples as input and calculates their correlation coefficient using NumPy.
#
# The function should return the correlation coefficient as a single numerical value.
#
# Test your function using the two generated samples and display the resulting correlation coefficient.
#
# You may find the following functionality useful: `np.random.seed`.

# %%
gaussian_sample_1 = ...
gaussian_sample_2 = ...

def correlation_coefficient(x, y):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 3 - Binomial Expansion
#
# Write a function that takes the coefficients of a binomial expression and a non-negative integer exponent as input, and returns the coefficients of the binomial raised to that exponent using NumPy's polynomial functions.
#
# The polynomial should be represented by a NumPy array of coefficients in **ascending order of powers**.
#
# For example, the polynomial
#
# $$1 + x$$
#
# is represented as:
#
# ```python
# np.array([1, 1])
# ```

# %%
def binomial_expansion(a, b, n):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 4 - System of Linear Equations
#
# Consider the following system of linear equations:
#
# \begin{align*}
# 2x - y + 3z &= 5\\
# x + y + 2z &= 8\\
# 3x - 2y + z &= 3
# \end{align*}​
#
#
# Write a Python function using NumPy that takes the coefficient matrix and the right-hand-side vector as inputs and solves the system of linear equations. The function should return the solution vector containing x, y, and z.

# %%
def solve_linear_system(A, b):
    #YOUR CODE HERE
    pass

# %% [markdown]
# # Question 5 - Map + Reduce: Find the Most Common Word
#
# Given a list of sentences:
#
# ```python
# sentences = [
#     "Python is easy to learn",
#     "Python is powerful",
#     "Learning Python is fun",
#     "Python makes programming fun"
# ]
# ```
#
# Using **`map()` and `reduce()`**, write a function that:
#
# 1. Converts all words to lowercase.
# 2. Removes the punctuation from each sentence.
# 3. Creates a frequency count of all words across all sentences.
# 4. Returns the word that occurs most frequently and its frequency.
#
# **Do not use explicit `for` or `while` loops**.

# %%
def most_common_word(sentences):
    # YOUR CODE HERE
    pass

# %% [markdown]
# # Q6 - Find the Closest Pair
#
# Write:
#
# ```python
# closest_students(grades, names)
# ```
#
# where each row of `grades` represents one student's feature vector.
#
# The function must find the **two distinct students with the smallest Euclidean distance** between their rows.
#
# Return:
#
# ```python
# (name1, name2, distance)
# ```
#
# where the names appear in their original order and `distance` is a floating-point value.
#
# ### Example
#
# ```python
# grades = np.array([
#     [80, 80],
#     [81, 81],
#     [20, 90]
# ])
#
# names = ["Amina", "Eric", "Grace"]
#
# closest_students(grades, names)
#
# # ("Amina", "Eric", 1.4142135623730951)
# ```
#
# ### Requirements
#
# - Students must not be compared with themselves.
# - The function must work for any number of features.
# - Do not construct a Python list of every pair of distances first.
#
# ### Tie rule
#
# If multiple pairs have exactly the same smallest distance, return the pair encountered first when considering pairs in the order:
#
# ```text
# (0,1), (0,2), (0,3), ..., (1,2), (1,3), ...
# ```

# %%
def closest_students(grades, names):
    #YOUR SOLUTION HERE
    pass

# %% [markdown]
# # Q7 - The Scientific Data Pipeline
#
# This is the final integration problem.
#
# Write:
#
# ```python
# process_experiment(filename, transform, threshold)
# ```
#
# The file contains one floating-point measurement per line.
#
# The function must:
#
# 1. read the measurements from the file;
# 2. ignore blank lines;
# 3. convert the measurements into a NumPy array;
# 4. apply the supplied function `transform` to the **whole NumPy array**;
# 5. keep only transformed values that are strictly greater than `threshold`;
# 6. return a dictionary containing:
#
# ```python
# {
#     "count": ...,
#     "mean": ...,
#     "maximum": ...,
#     "values": ...
# }
# ```
#
# where `values` is a NumPy array containing the retained values.
#
# Example file:
#
# ```text
# 1
# 2
# 3
# 4
# 5
# ```
#
# and:
#
# ```python
# process_experiment(
#     filename,
#     lambda x: x ** 2,
#     8
# )
# ```
#
# should conceptually produce:
#
# ```python
# {
#     "count": 3,
#     "mean": 16.666666666666668,
#     "maximum": 25,
#     "values": np.array([9, 16, 25])
# }
# ```
#
# - `transform` is a function passed into your function.
# - The transformation must operate on the NumPy array directly.
# - Use NumPy boolean masking for the threshold.
# - Read the file with `with open(...)`.
# - Do not hard-code the transformation.
# - Return `count = 0`, `mean = 0.0`, `maximum = None`, and an empty NumPy array if no transformed value passes the threshold.
#
# Your implementation must genuinely pass the **whole array** to `transform`.
#
# <span style="color:red">You can use `experiment_data.txt` to test your work for this question. Make sure to save it in the same working directory as your notebook.</span>

# %%
def process_experiment(transform, threshold, filename='experiment_data.txt'):
    #YOUR SOLUTION HERE
    pass
